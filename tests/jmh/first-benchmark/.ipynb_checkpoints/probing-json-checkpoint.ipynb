# %%
import json
import statistics

# %%
with open('jmh-result.json') as f:
    data = json.loads(f.read())
data
# Out:
# [{'jmhVersion': '1.27',
#   'benchmark': 'jRAPL.EnergySampling.timeGetPrimitiveSample',
#   'mode': 'avgt',
#   'threads': 1,
#   'forks': 5,
#   'jvm': '/usr/lib/jvm/java-11-openjdk-amd64/bin/java',
#   'jvmArgs': [],
#   'jdkVersion': '11.0.9',
#   'vmName': 'OpenJDK 64-Bit Server VM',
#   'vmVersion': '11.0.9+11-Ubuntu-0ubuntu1.20.04',
#   'warmupIterations': 5,
#   'warmupTime': '10 s',
#   'warmupBatchSize': 1,
#   'measurementIterations': 5,
#   'measurementTime': '10 s',
#   'measurementBatchSize': 1,
#   'primaryMetric': {'score': 8.788162666319382,
#    'scoreError': 2.173418145658022,
#    'scoreConfidence': [6.614744520661359, 10.961580811977404],
#    'scorePercentiles': {'0.0': 5.5122313728062515,
#     '50.0': 7.846831876336387,
#     '90.0': 14.160375462021292,
#     '95.0': 14.656569907071852,
#     '99.0': 14.833481832206004,
#     '99.9': 14.833481832206004,
#     '99.99': 14.833481832206004,
#     '99.999': 14.833481832206004,
#     '99.9999': 14.833481832206004,
# ...

# %%
sample = data[0]
metric = sample['primaryMetric']
raw = metric['rawData']
avg = statistics.mean([statistics.mean(r) for r in raw])
print(metric['score'])
print(avg)
sample
# Out:
# 8.788162666319382
# 8.78816266631938
# {'jmhVersion': '1.27',
#  'benchmark': 'jRAPL.EnergySampling.timeGetPrimitiveSample',
#  'mode': 'avgt',
#  'threads': 1,
#  'forks': 5,
#  'jvm': '/usr/lib/jvm/java-11-openjdk-amd64/bin/java',
#  'jvmArgs': [],
#  'jdkVersion': '11.0.9',
#  'vmName': 'OpenJDK 64-Bit Server VM',
#  'vmVersion': '11.0.9+11-Ubuntu-0ubuntu1.20.04',
#  'warmupIterations': 5,
#  'warmupTime': '10 s',
#  'warmupBatchSize': 1,
#  'measurementIterations': 5,
#  'measurementTime': '10 s',
#  'measurementBatchSize': 1,
#  'primaryMetric': {'score': 8.788162666319382,
#   'scoreError': 2.173418145658022,
#   'scoreConfidence': [6.614744520661359, 10.961580811977404],
#   'scorePercentiles': {'0.0': 5.5122313728062515,
#    '50.0': 7.846831876336387,
#    '90.0': 14.160375462021292,
#    '95.0': 14.656569907071852,
#    '99.0': 14.833481832206004,
#    '99.9': 14.833481832206004,
#    '99.99': 14.833481832206004,
#    '99.999': 14.833481832206004,
# ...
